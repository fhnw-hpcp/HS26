# %% [markdown]
# ![FS_Slide](img/HPCP_FS/Folie1.PNG)

# %% [markdown]
# ![FS_Slide](img/HPCP_FS/Folie2.PNG)

# %% [markdown]
# ![FS_Slide](img/HPCP_FS/Folie3.PNG)

# %% [markdown]
# ![FS_Slide](img/HPCP_FS/Folie4.PNG)

# %% [markdown]
# ![FS_Slide](img/HPCP_FS/Folie5.PNG)

# %% [markdown]
# ![Kernel](img/Linux-storage-stack-diagram_v6.16.png)

# %% [markdown]
# ### Case Study: Optimizing File Access Patterns (FITS vs. Sorted vs. HDF5)
#
# Background: The Euclid space telescope (ESA mission) produces large images of the sky. Imagine a single, very large FITS file that packs numerous galaxies spread across multiple HDUs (Header/Data Units). In our case, each image is segmented into a 6×6 grid of detectors, and each detector is further split into 4 quadrants, yielding 36 × 4 = 144 HDUs/headers per image. FITS (Flexible Image Transport System) is a classic astrophysics file format: it stores data (images, tables) with text headers describing them. A FITS file might contain one primary image and many extension images; each extension has a 2880-byte aligned header and then data. The Euclid processing code needs to extract and process millions of galaxies stored in these files. Our code is extracting galaxy stamps - small cut-out images - of each galaxy for further processing.
#
# **Problem**: Accessing those stamps in the naive way
#
# * Seek to its location in the FITS file (which might be a random position if stamps are scattered).
# * Read the small chunk of bytes that make up that stamp (maybe each stamp is, say, 100×100 pixels – about 10,000 elements, which at 4 bytes each is 40 KB).
# * Move on to the next stamp.
#
# If the stamps are not in file order, this results in random reads all over a very large file. Each small read will likely trigger the filesystem to load a full block (e.g., 4 MB) from disk, of which only 40 KB are used – the rest is “wasted” overhead. Also, each access may require re-reading FITS headers or jumping to different extensions, incurring extra overhead in the FITS library (parsing the header). In short, the pattern is: open file, seek, read 40 KB, seek somewhere far, read 40 KB, … repeated thousands of times.

# %%
from pathlib import Path
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
from scipy.spatial import KDTree
import time
import os

import json

from stampextraction.vis_exposures import VisExposureFitsIO, VisExposureHDF5
from stampextraction.stamps import extract_exposure_stamp

# %%
#Define files
datafiles = {}
datafiles["DET"] = "EUC_SHE_VIS-DET-1-1_0_20250701T085217.429173Z_09.10.fits"
datafiles["BKG"] = "EUC_SHE_VIS-BKG-1-1_0_20250701T085217.429307Z_09.10.fits"
datafiles["WGT"] = "EUC_SHE_VIS-WGT-1-1_0_20250701T085217.429294Z_09.10.fits"
datafiles["SEG"] = "EUC_SHE_EXP-RPJ-SEG_00_20250701T085301.676748Z_09.10.fits"
datafiles["MER"] = "EUC_SHE_MER-CAT_00_20250701T085255.628039Z_09.10.fits"
datafiles["HDF5"] = "image_data.hdf5"

# If working on Merlin at PSI
datapath = Path("/data/scratch/shared/hpcp")

# If working on the Calculon at FHNW
#datapath = Path("/shared-scratch/hpcp/data")

# %% [markdown]
# #### The Euclid data set
# The Euclid Catalog FITS file contains about 144,000 galaxy objects in this simulated image, each with many recorded properties.
# For this example, we are only interested in three fields:
#
# - `OBJECT_ID`
# - `RIGHT_ASCENSION`
# - `DECLINATION`
#
# Let’s open the catalog and take a first look.

# %%
from astropy.table import Table
mer_table = Table.read(datapath / datafiles["MER"], memmap=False)
mer_table[0:10]
# Out:
# <Table length=10>
# OBJECT_ID   RIGHT_ASCENSION         DECLINATION       ... GAL_EBV GAL_EBV_ERR
#   int64         float64               float64         ... float32   float32
# --------- -------------------- ---------------------- ... ------- -----------
#    144000    359.9986666666669  -0.021611110080396057 ...     0.0         0.0
#    144001    359.9744722239114  0.0023055553254781123 ...     0.0         0.0
#    144002   359.97838888991373 -0.0029999997838516686 ...     0.0         0.0
#    144003 0.008277777720181826    0.01822222141766508 ...     0.0         0.0
#    144004 0.004611111101147193 -0.0014722222171242199 ...     0.0         0.0
#    144005 0.024138887460701242  -0.024555551872864338 ...     0.0         0.0
#    144006   359.97269444651164   0.016499997670129867 ...     0.0         0.0
#    144007 0.007333333293289201  -0.014027777382589845 ...     0.0         0.0
#    144008    359.9888611112514   0.008111110903644336 ...     0.0         0.0
#    144009    359.9947500000147   0.007972222137294113 ...     0.0         0.0

# %% [markdown]
# Lets have a look at the detector file. A Fits file with 3 extensions for each quadrant. We have a grid of 6x6 CCDs, each consists of 4 quadrants. So the FITS file contains 432 HDUs:
# *  SCI: VIS science imag
# *  RMS: quadrant readout noise
# *  FLG: quality-control image

# %%
hdu_list = fits.open(datapath / datafiles["DET"])
hdu_list.info()
# Out:
# Filename: /data/scratch/shared/hpcp/EUC_SHE_VIS-DET-1-1_0_20250701T085217.429173Z_09.10.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     192   ()
#   1  1-1.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
#   2  1-1.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
#   3  1-1.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
#   4  1-1.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
#   5  1-1.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
#   6  1-1.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
#   7  1-1.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
#   8  1-1.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
#   9  1-1.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  10  1-1.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  11  1-1.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  12  1-1.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  13  1-2.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  14  1-2.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  15  1-2.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  16  1-2.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  17  1-2.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  18  1-2.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  19  1-2.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  20  1-2.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  21  1-2.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  22  1-2.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  23  1-2.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  24  1-2.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  25  1-3.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  26  1-3.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  27  1-3.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  28  1-3.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  29  1-3.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  30  1-3.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  31  1-3.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  32  1-3.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  33  1-3.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  34  1-3.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  35  1-3.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  36  1-3.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  37  1-4.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  38  1-4.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  39  1-4.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  40  1-4.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  41  1-4.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  42  1-4.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  43  1-4.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  44  1-4.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  45  1-4.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  46  1-4.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  47  1-4.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  48  1-4.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  49  1-5.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  50  1-5.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  51  1-5.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  52  1-5.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  53  1-5.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  54  1-5.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  55  1-5.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  56  1-5.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  57  1-5.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  58  1-5.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  59  1-5.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  60  1-5.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  61  1-6.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  62  1-6.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  63  1-6.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  64  1-6.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  65  1-6.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  66  1-6.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  67  1-6.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  68  1-6.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  69  1-6.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  70  1-6.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  71  1-6.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  72  1-6.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  73  2-1.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  74  2-1.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  75  2-1.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  76  2-1.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  77  2-1.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  78  2-1.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  79  2-1.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  80  2-1.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  81  2-1.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  82  2-1.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  83  2-1.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  84  2-1.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  85  2-2.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  86  2-2.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  87  2-2.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  88  2-2.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  89  2-2.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  90  2-2.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  91  2-2.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  92  2-2.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  93  2-2.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  94  2-2.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  95  2-2.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  96  2-2.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
#  97  2-3.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
#  98  2-3.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
#  99  2-3.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 100  2-3.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 101  2-3.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 102  2-3.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 103  2-3.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 104  2-3.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 105  2-3.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 106  2-3.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 107  2-3.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 108  2-3.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 109  2-4.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 110  2-4.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 111  2-4.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 112  2-4.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 113  2-4.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 114  2-4.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 115  2-4.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 116  2-4.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 117  2-4.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 118  2-4.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 119  2-4.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 120  2-4.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 121  2-5.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 122  2-5.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 123  2-5.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 124  2-5.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 125  2-5.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 126  2-5.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 127  2-5.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 128  2-5.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 129  2-5.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 130  2-5.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 131  2-5.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 132  2-5.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 133  2-6.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 134  2-6.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 135  2-6.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 136  2-6.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 137  2-6.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 138  2-6.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 139  2-6.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 140  2-6.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 141  2-6.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 142  2-6.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 143  2-6.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 144  2-6.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 145  3-1.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 146  3-1.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 147  3-1.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 148  3-1.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 149  3-1.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 150  3-1.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 151  3-1.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 152  3-1.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 153  3-1.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 154  3-1.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 155  3-1.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 156  3-1.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 157  3-2.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 158  3-2.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 159  3-2.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 160  3-2.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 161  3-2.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 162  3-2.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 163  3-2.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 164  3-2.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 165  3-2.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 166  3-2.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 167  3-2.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 168  3-2.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 169  3-3.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 170  3-3.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 171  3-3.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 172  3-3.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 173  3-3.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 174  3-3.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 175  3-3.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 176  3-3.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 177  3-3.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 178  3-3.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 179  3-3.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 180  3-3.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 181  3-4.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 182  3-4.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 183  3-4.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 184  3-4.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 185  3-4.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 186  3-4.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 187  3-4.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 188  3-4.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 189  3-4.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 190  3-4.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 191  3-4.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 192  3-4.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 193  3-5.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 194  3-5.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 195  3-5.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 196  3-5.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 197  3-5.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 198  3-5.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 199  3-5.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 200  3-5.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 201  3-5.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 202  3-5.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 203  3-5.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 204  3-5.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 205  3-6.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 206  3-6.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 207  3-6.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 208  3-6.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 209  3-6.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 210  3-6.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 211  3-6.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 212  3-6.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 213  3-6.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 214  3-6.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 215  3-6.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 216  3-6.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 217  4-1.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 218  4-1.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 219  4-1.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 220  4-1.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 221  4-1.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 222  4-1.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 223  4-1.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 224  4-1.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 225  4-1.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 226  4-1.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 227  4-1.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 228  4-1.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 229  4-2.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 230  4-2.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 231  4-2.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 232  4-2.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 233  4-2.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 234  4-2.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 235  4-2.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 236  4-2.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 237  4-2.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 238  4-2.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 239  4-2.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 240  4-2.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 241  4-3.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 242  4-3.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 243  4-3.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 244  4-3.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 245  4-3.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 246  4-3.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 247  4-3.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 248  4-3.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 249  4-3.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 250  4-3.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 251  4-3.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 252  4-3.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 253  4-4.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 254  4-4.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 255  4-4.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 256  4-4.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 257  4-4.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 258  4-4.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 259  4-4.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 260  4-4.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 261  4-4.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 262  4-4.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 263  4-4.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 264  4-4.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 265  4-5.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 266  4-5.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 267  4-5.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 268  4-5.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 269  4-5.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 270  4-5.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 271  4-5.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 272  4-5.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 273  4-5.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 274  4-5.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 275  4-5.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 276  4-5.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 277  4-6.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 278  4-6.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 279  4-6.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 280  4-6.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 281  4-6.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 282  4-6.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 283  4-6.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 284  4-6.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 285  4-6.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 286  4-6.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 287  4-6.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 288  4-6.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 289  5-1.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 290  5-1.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 291  5-1.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 292  5-1.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 293  5-1.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 294  5-1.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 295  5-1.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 296  5-1.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 297  5-1.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 298  5-1.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 299  5-1.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 300  5-1.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 301  5-2.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 302  5-2.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 303  5-2.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 304  5-2.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 305  5-2.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 306  5-2.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 307  5-2.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 308  5-2.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 309  5-2.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 310  5-2.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 311  5-2.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 312  5-2.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 313  5-3.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 314  5-3.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 315  5-3.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 316  5-3.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 317  5-3.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 318  5-3.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 319  5-3.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 320  5-3.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 321  5-3.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 322  5-3.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 323  5-3.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 324  5-3.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 325  5-4.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 326  5-4.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 327  5-4.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 328  5-4.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 329  5-4.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 330  5-4.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 331  5-4.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 332  5-4.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 333  5-4.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 334  5-4.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 335  5-4.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 336  5-4.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 337  5-5.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 338  5-5.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 339  5-5.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 340  5-5.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 341  5-5.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 342  5-5.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 343  5-5.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 344  5-5.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 345  5-5.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 346  5-5.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 347  5-5.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 348  5-5.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 349  5-6.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 350  5-6.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 351  5-6.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 352  5-6.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 353  5-6.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 354  5-6.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 355  5-6.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 356  5-6.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 357  5-6.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 358  5-6.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 359  5-6.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 360  5-6.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 361  6-1.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 362  6-1.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 363  6-1.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 364  6-1.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 365  6-1.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 366  6-1.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 367  6-1.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 368  6-1.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 369  6-1.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 370  6-1.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 371  6-1.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 372  6-1.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 373  6-2.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 374  6-2.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 375  6-2.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 376  6-2.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 377  6-2.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 378  6-2.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 379  6-2.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 380  6-2.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 381  6-2.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 382  6-2.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 383  6-2.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 384  6-2.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 385  6-3.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 386  6-3.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 387  6-3.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 388  6-3.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 389  6-3.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 390  6-3.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 391  6-3.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 392  6-3.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 393  6-3.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 394  6-3.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 395  6-3.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 396  6-3.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 397  6-4.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 398  6-4.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 399  6-4.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 400  6-4.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 401  6-4.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 402  6-4.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 403  6-4.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 404  6-4.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 405  6-4.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 406  6-4.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 407  6-4.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 408  6-4.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 409  6-5.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 410  6-5.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 411  6-5.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 412  6-5.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 413  6-5.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 414  6-5.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 415  6-5.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 416  6-5.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 417  6-5.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 418  6-5.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 419  6-5.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 420  6-5.H.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 421  6-6.E.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 422  6-6.E.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 423  6-6.E.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 424  6-6.F.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 425  6-6.F.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 426  6-6.F.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 427  6-6.G.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 428  6-6.G.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 429  6-6.G.FLG     1 ImageHDU        65   (2048, 2048)   int32
# 430  6-6.H.SCI     1 ImageHDU        65   (2048, 2048)   float32
# 431  6-6.H.RMS     1 ImageHDU        65   (2048, 2048)   float32
# 432  6-6.H.FLG     1 ImageHDU        65   (2048, 2048)   int32

# %% [markdown]
# Let us have a closer look at a single image of a single quadrant:

# %%
plt.figure(figsize = (12,12))
plt.imshow(hdu_list[1].data, cmap="gray")

# %% [markdown]
# This is a simulated image, with uniform sources. Perfectly for our use case: For each source make a cut-out of the image (called a stamp) and then do some processing on this.
# A real Euclid image looks quiet differently, like this:
# ![GPU Basics Slide](img/VIS_exposure.png)
# src: https://arxiv.org/pdf/2503.15303

# %% [markdown]
# We create a JSON file named **`shuffled_batches.json`**, which stores a dump of a `List[List[int]]`.
# - Each inner list represents a batch of indices to be processed by one process.
# - The data is split into **1000 batches** and then **randomly shuffled**.
#
# This setup simulates the **worst-case access pattern** for our shared filesystem.

# %%
shuffled_ids = np.random.permutation([i for i in range(len(mer_table))])
shuffled_batches = [[int(i) for i in batch] for batch in np.array_split(shuffled_ids, 1000)]
Path("profiling").mkdir(exist_ok=True)
with open("profiling/shuffled_batches.json", "w") as f:
    json.dump(shuffled_batches, f)

# %% [markdown]
# #### Task 1
#
# Create a shell script named **`profiling/stamp_processing_fits_shuffled.sh`**.
# This script should run the following command:
#
# ```bash
# conda run -n summer-school-hpc-2025 mpirun --use-hwthread-cpus python execute_on_batch.py shuffled fits
# ```
#
# What this does:
#
# * Launches the stamp extraction step.
# * Each MPI rank loads one batch from the shuffled list.
# * Only one batch is processed per rank (i.e., not all batches are processed - except if we use 1000 processes).
# * For each object ID in the batch, the code creates a galaxy cut-out (stamp).
# * No further processing is done on the stamp; instead, the code calls time.sleep(0.5) to simulate computation time.
#
# Important:
#
# * The script will be submitted via sbatch, so you should include appropriate SBATCH directives
# * To make mpirun work correctly on the cluster, additional setup is required
# * → We will discuss these details together in class.

# %%
# %%writefile profiling/stamp_processing_fits_shuffled.sh
# #!/bin/bash
#
# #SBATCH --hint=multithread
#
# module load anaconda
# cd /data/user/${USER}/HS26/04_Advanced
# export PYTHONPATH=/data/user/${USER}/HS26/04_Advanced:$PYTHONPATH
# conda run -n summer-school-hpc-2025 mpirun --use-hwthread-cpus python stampextraction/execute_on_batch.py
# Out:
# Overwriting profiling/stamp_processing_fits_shuffled.sh

# %%
# !chmod +x profiling/stamp_processing_fits_shuffled.sh

# %% [markdown]
# Let's give it a try and execute it on the cluster!
#
# ```bash
# sbatch --ntasks=2 --output=stamp_fits_shuffled.out profiling/stamp_processing_fits_shuffled.sh
# ```

# %%
# !sacct -j 6288555
# Out:
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 6288555      stamp_pro+    general     merlin          2    RUNNING      0:0
# 6288555.bat+      batch                merlin          2    RUNNING      0:0
# 6288555.ext+     extern                merlin          2    RUNNING      0:0

# %% [markdown]
# We provide a helper function to visualize profiling results from our runs:
#
# ```python
# plot_profiling(
#     file_types=["fits", "hdf5"],
#     sorting_types=["shuffled", "sorted"],
#     prefixes=[""],
#     sizes=[1, 2, 4, 8, 16, 32, 64, 128, 256, 512]
# )
# ```
# * file_types: select which file formats to include (e.g., "fits", "hdf5")
# * sorting_types: choose the access pattern (e.g., "shuffled", "sorted")
# * sizes: define the batch sizes or number of ranks to plot
#
# Use these arguments to control which experiments are compared in the plot.

# %%
def plot_profiling(file_types=["fits", "hdf5"], sorting_types=["shuffled", "sorted"],
                   prefixes=[""], sizes=[1,2,4,8,16,32,64,128,256,512]):
    fig, axs = plt.subplots(3, 2, figsize=(10, 10))
    fig.suptitle("Profiling stats – mean for a single stamp extraction over time", fontsize=14)
    for file_type in file_types:
        for sorting_type in sorting_types:
            for size in sizes:
                for prefix in prefixes:
                    if os.path.exists(f"profiling/{prefix}profiling_{file_type}_{sorting_type}_{size}.json"):
                        with open(f"profiling/{prefix}profiling_{file_type}_{sorting_type}_{size}.json") as f:
                            json_list = [json.loads(line) for line in f]
                        ticks = [item["tick"] for item in json_list]
                        walltime = [item["walltime"] for item in json_list]
                        axs[0,0].plot(ticks, walltime, marker='o', label=f"{prefix}{file_type}_{sorting_type}_{size}")
                        axs[0,0].set_ylabel("Execution Time [ms]")
                        read_ops = [item["read_ops"] for item in json_list]
                        axs[0,1].plot(ticks, read_ops, marker='o', label=f"{prefix}{file_type}_{sorting_type}_{size}")
                        axs[0,1].set_ylabel("read ops")
                        read_bytes = [item["read"] for item in json_list]
                        axs[1,0].plot(ticks, read_bytes, marker='o', label=f"{prefix}{prefix}{file_type}_{sorting_type}_{size}")
                        axs[1,0].set_ylabel("read [KB]")
                        open_files = [item["open_files"] for item in json_list]
                        axs[1,1].plot(ticks, open_files, marker='o', label=f"{prefix}{file_type}_{sorting_type}_{size}")
                        axs[1,1].set_ylabel("open files [FD]")
                        rss = [item["rss"] for item in json_list]
                        axs[2,0].plot(ticks, rss, marker='o', label=f"{prefix}{file_type}_{sorting_type}_{size}")
                        axs[2,0].set_ylabel("Memory (rss) [MB]")
                        vms = [item["vms"] for item in json_list]
                        axs[2,1].plot(ticks, vms, marker='o', label=f"{prefix}{file_type}_{sorting_type}_{size}")
                        axs[2,1].set_ylabel("Memory (vms) [MB]")

    for ax in axs.flat:
        ax.set_xticks([])  
        ax.set_xlabel("-- time -->")
    
    handles, labels = axs[0, 0].get_legend_handles_labels()
    fig.legend(handles, labels, loc="upper center", ncol=len(labels), bbox_to_anchor=(0.5, 0.96))
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# %%
plot_profiling(file_types=["fits"], sorting_types=["shuffled"],sizes=[2])

# %% [markdown]
# ![FS_Slide](img/HPCP_FS/Folie6.PNG)

# %% [markdown]
# #### Task 2
#
# Modify the experiment to run with **32 processes**.
# - In this case, the **GPFS pagepool cache** will be shared among all processes, increasing contention.
# - On the Merlin 6 nodes, the default pagepool size is **6 GB**.
#
# Next, repeat the test with **32 processes**, but request the reservation **`sschool25_small`**.
# - These nodes have only **1 GB pagepool**.
#
# **Question:** Do you observe a significant difference in performance between 6 GB and 1 GB pagepool? Plot the results. You have to rename the coresponding profiling file to 1GB_GPFS_... and 6GB_GPFS_... to be able to use the plot as bellow.
#
# Hint: `sbatch --ntasks=32 --output=stamp_fits_shuffled.out profiling/stamp_processing_fits_shuffled.sh`

# %%
plot_profiling(file_types=["fits"], sorting_types=["shuffled"], sizes=[32], prefixes=["1GB_GPFS_", "6GB_GPFS_"])

# %% [markdown]
# #### Task 3
#
# Increase the number of processes and observe how this affects performance.
# - With multiple nodes accessing the same file concurrently, the **shared filesystem** experiences additional pressure.
# - Run the experiment with **62, 128, 256, and 512 processes**.
#
# Finally, **plot the results** to visualize the scaling behavior.

# %%
plot_profiling(file_types=["fits"], sorting_types=["shuffled"],sizes=[2,32,64,128,256,512])

# %% [markdown]
# **This is an image from the Merlin6 Cluster running on a GPFS file system:**
#
# ![GPS_Img](img/plot_gpfs_1.png)

# %% [markdown]
# We observe that extracting a single stamp takes about **0.1 seconds** when running on a single node.
# With **512 processes**, the time increases to roughly **2.5 seconds per extraction** — a **25× slowdown**!
#
# Note that 512 processes is not an unusually high number on this cluster (it supports far more), but our goal here is not to bring the entire system to a halt.

# %% [markdown]
# ![FS_Slide](img/HPCP_FS/Folie7.PNG)

# %% [markdown]
# #### Task 4
#
# Reorder the dataset so that **spatially close objects are grouped together**.
# We can achieve this by building a **KD-Tree**.
#
# To construct the KD-Tree, first convert **RA** and **DEC** into Cartesian coordinates **(X, Y, Z)** using:
#
# $$
# \begin{aligned}
# X &= \cos B \cdot \cos A \\
# Y &= \cos B \cdot \sin A \\
# Z &= \sin B
# \end{aligned}
# $$
#
# **Hints:**
# 1. Use `np.radians()` to convert RA/DEC into radians before applying the formula.
# 2. Build the KD-Tree input as: `xyz = np.asarray([x, y, z]).T` This is the format the KD-Tree expects.
#
# Finally, split the data into 1000 batches and write them to the file: profiling/sorted_batches.json

# %%
ra = mer_table["RIGHT_ASCENSION"]
dec = mer_table["DECLINATION"]
ids = mer_table["OBJECT_ID"]

# ToDo: Use the KDTree to sort the ids based on their spatial proximity

sorted_inds = tree.indices
sorted_batches = [[int(i) for i in batch] for batch in np.array_split(sorted_inds, 1000)]

with open("profiling/sorted_batches.json", "w") as f:
    json.dump(sorted_batches, f)

# %% [markdown]
# #### Task 5
#
# Run experiments using the **sorted batches**.
# Modify the execution command as follows:
#
# ```bash
# conda run -n summer-school-hpc-2025 mpirun --use-hwthread-cpus python execute_on_batch.py sorted fits
# ```
#
# After running the experiments, plot your results and be prepared to discuss your observations in class.

# %%
# %%writefile profiling/stamp_processing_fits_sorted.sh
# #!/bin/bash
#
# #SBATCH --hint=multithread
#
# module load anaconda
# cd /data/user/${USER}/HS26/04_Advanced
# export PYTHONPATH=/data/user/${USER}/HS26/04_Advanced/04_Advanced:$PYTHONPATH
# conda run -n summer-school-hpc-2025 mpirun --use-hwthread-cpus python stampextraction/execute_on_batch.py sorted fits
# Out:
# Writing profiling/stamp_processing_fits_sorted.sh

# %% [markdown]
# ```bash
# sbatch --ntasks=32  --output=stamp_fits_sorted.out profiling/stamp_processing_fits_sorted.sh
# ```

# %%
plot_profiling(file_types=["fits"], sorting_types=["shuffled", "sorted"],sizes=[2,32,512])

# %% [markdown]
# **This is an image from the Merlin6 Cluster running on a GPFS file system:**
#
# ![GPS_Img](img/plot_gpfs_2.png)

# %% [markdown]
# ![FS_Slide](img/HPCP_FS/Folie8.PNG)

# %% [markdown]
# #### Task 6
#
# Run experiments using the HDF5 file format. There is already a converted file available.
# Modify the execution command as follows:
#
# ```bash
# conda run -n summer-school-hpc-2025 mpirun --use-hwthread-cpus python execute_on_batch.py sorted hdf5
# ```
#
# After running the experiments, plot your results and be prepared to discuss your observations in class.

# %%
# %%writefile profiling/stamp_processing_hdf5_sorted.sh
# #!/bin/bash
#
# #SBATCH --hint=multithread
#
# module load anaconda
# cd /data/user/${USER}/HS26/04_Advanced
# export PYTHONPATH=/data/user/${USER}/HS26/04_Advanced/04_Advanced:$PYTHONPATH
# conda run -n summer-school-hpc-2025 mpirun --use-hwthread-cpus python stampextraction/execute_on_batch.py sorted hdf5
# Out:
# Writing profiling/stamp_processing_hdf5_sorted.sh

# %%
# %%writefile profiling/stamp_processing_hdf5_shuffled.sh
# #!/bin/bash
#
# #SBATCH --hint=multithread
#
# module load anaconda
# cd /data/user/${USER}/HS26/04_Advanced
# export PYTHONPATH=/data/user/${USER}/HS26/04_Advanced/04_Advanced:$PYTHONPATH
# conda run -n summer-school-hpc-2025 mpirun --use-hwthread-cpus python stampextraction/execute_on_batch.py shuffled hdf5
# Out:
# Writing profiling/stamp_processing_hdf5_shuffled.sh

# %% [markdown]
# ```bash
# sbatch --ntasks=2  --output=stamp_hdf5_sorted.out profiling/stamp_processing_hdf5_sorted.sh
# sbatch --ntasks=2  --output=stamp_hdf5_sorted.out profiling/stamp_processing_hdf5_shuffled.sh
# ```

# %%
plot_profiling(file_types=["fits", "hdf5"], sorting_types=["shuffled", "sorted"],sizes=[2])

# %% [markdown]
# **This is an image from the Merlin6 Cluster running on a GPFS file system:**
#
# ![GPS_Img](img/plot_gpfs_3.png)

# %%
plot_profiling(file_types=["fits", "hdf5"], sorting_types=["shuffled", "sorted"],sizes=[32, 256])

# %% [markdown]
# **This is an image from the Merlin6 Cluster running on a GPFS file system:**
#
# ![GPS_Img4](img/plot_gpfs_4.png)

# %% [markdown]
# ![FS_Slide](img/HPCP_FS/Folie9.PNG)

# %% [markdown]
# ![FS_Slide](img/HPCP_FS/Folie10.PNG)
